# %%
"""
This script can be used for recreating the link prediction results for different parameter settings
and dimensionality
"""
import argparse
from datetime import datetime
import random
import numpy as np
import os
import time
from utils import *
from params import *
import sys
from datetime import date
import pickle
import train_inductive
# should we not make a seperate config for out "official runnings"
from trials.hyperparam_config import config
import pickle
import optuna
import copy
from utils.train_utils import get_dir_name, format_metrics
from main import parse_default_args
from hyperparam import create_study_output_dir,create_objective_fun,complete_study_one_arg
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from trials.hyperparam_config import config
from main import parse_default_args

# %%
BAND_TO_OPT_C= { 
           'alpha':.54,
           'gamma':.66,
           'beta': .74,
            'theta':None
}

# %%
hyp_arch_dict={'model':'HGCN','optimizer':'RiemannianAdam','manifold':'PoincareBall'}
euc_arch_dict={'model':'GCN','optimizer':'Adam','manifold':'Euclidean'}

# %%
mod_types={'full':{'use_weight':1,'use_virtual':1},
            'no_virt':{'use_weight':1,'use_virtual':0},
                'no_weight':{'use_weight':0,'use_virtual':1}}

input_types={'plv':{'use_plv':1,'use_identity':0},'id':{'use_plv':0,'use_identity':1}}


curve_types={'setc':{**hyp_arch_dict,'c':'set'},
            'findc':{**hyp_arch_dict,'c':None},
            '1c':{**hyp_arch_dict,'c':1},
             'euc':{**euc_arch_dict,'c':0}}

# %%
# the total number of validation runs that all should have
NUM_VALIDATIONS=2
criteria={'CogTr':1}
set_args={'dataset':'meg',
          'task':'lp',
          'criteria_dict':{}}
criteria=criteria
output_dims=[2,3,4]
mod_types_to_use=['full','no_virt','no_weight']
input_types_to_use=['id']
curve_types_to_use=['findc','1c','euc']
best=set(['full','findc','id'])
for d in output_dims:
    for i in input_types_to_use:
        inp_dict=input_types[i]
        inf_inp=0 if (i in best) else 1
        for c_type in curve_types_to_use:
            inf_c=0 if (c_type in best) else 1
#             print(c,'C')
#             print(c_dict,'C DICT?')
            c_dict=curve_types[c_type]
#             print(c_dict,'')
            c_val=c_dict['c']
            print(c_val,'C VAL')
#             if not inf_c:
#                 print(c,'c!!')
#                 sksks
            if c_val=='set':
                c_set=BAND_TO_OPT_C['alpha']
                c_dict['c']=c_set
                
            for m in mod_types_to_use:
                mod_dict=mod_types[m]
                inf_m=0 if (m in best) else 1
                # only need one ablation at a time
#                 print(inf_m+inf_c,'INF M C')
#                 print(inf_m,inf_c,'both')
#                 print(mod_dict,'BEOFRE?')
#                 print(inf_c,'INF C?')
                if inf_m+inf_c>1:
                    continue
            
                
                set_args = copy.deepcopy(set_args)
                set_args['output_dim']=d
                set_args.update(c_dict)
                set_args.update(mod_dict)
                set_args.update(inp_dict)
                args = parse_default_args(set_args)
                #             print(set_args['c'],set_args['use_identity'],set_args['use_plv'])
                print('compase')
                print('C: {}, ID: {}, PLV {}'.format(set_args['c'],set_args['use_identity'],set_args['use_plv']))
                print('C: {}, ID: {}, PLV {}'.format(args.c,args.use_identity,args.use_plv))
                print('Virt: {}, Weight: {}, C {}'.format(args.use_virtual,args.use_weight,args.c))
                #             akak
                print(args.criteria_dict)
                complete_study_one_arg(args,NUM_VALIDATIONS)
            
            

# # c=[1,None,.54]
# args = parse_default_args(set_args) ### still need to call this with args for dataset, possibly others
# complete_study_one_arg(args,NUM_VALIDATIONS)
# # print(args)
# # change_task(args,)
# # 
# # setattr(args,'criteria_dict',criteria)
# Out:
# None C VAL
# {'use_weight': 1, 'use_virtual': 1} BEOFRE?
# 0 INF C?
# {'use_weight': 1, 'use_virtual': 1} THROUG?
# {'use_weight': 1, 'use_virtual': 0} BEOFRE?
# 0 INF C?
# {'use_weight': 1, 'use_virtual': 0} THROUG?
# {'use_weight': 0, 'use_virtual': 1} BEOFRE?
# 0 INF C?
# {'use_weight': 0, 'use_virtual': 1} THROUG?
# 1 C VAL
# {'use_weight': 1, 'use_virtual': 1} BEOFRE?
# 1 INF C?
# {'use_weight': 1, 'use_virtual': 1} THROUG?
# {'use_weight': 1, 'use_virtual': 0} BEOFRE?
# 1 INF C?
# {'use_weight': 0, 'use_virtual': 1} BEOFRE?
# 1 INF C?
# 0 C VAL
# {'use_weight': 1, 'use_virtual': 1} BEOFRE?
# 1 INF C?
# {'use_weight': 1, 'use_virtual': 1} THROUG?
# {'use_weight': 1, 'use_virtual': 0} BEOFRE?
# 1 INF C?
# {'use_weight': 0, 'use_virtual': 1} BEOFRE?
# 1 INF C?
# None C VAL
# {'use_weight': 1, 'use_virtual': 1} BEOFRE?
# 0 INF C?
# {'use_weight': 1, 'use_virtual': 1} THROUG?
# {'use_weight': 1, 'use_virtual': 0} BEOFRE?
# 0 INF C?
# {'use_weight': 1, 'use_virtual': 0} THROUG?
# {'use_weight': 0, 'use_virtual': 1} BEOFRE?
# 0 INF C?
# {'use_weight': 0, 'use_virtual': 1} THROUG?
# 1 C VAL
# {'use_weight': 1, 'use_virtual': 1} BEOFRE?
# 1 INF C?
# {'use_weight': 1, 'use_virtual': 1} THROUG?
# {'use_weight': 1, 'use_virtual': 0} BEOFRE?
# 1 INF C?
# {'use_weight': 0, 'use_virtual': 1} BEOFRE?
# 1 INF C?
# 0 C VAL
# {'use_weight': 1, 'use_virtual': 1} BEOFRE?
# 1 INF C?
# {'use_weight': 1, 'use_virtual': 1} THROUG?
# {'use_weight': 1, 'use_virtual': 0} BEOFRE?
# 1 INF C?
# {'use_weight': 0, 'use_virtual': 1} BEOFRE?
# 1 INF C?
# None C VAL
# {'use_weight': 1, 'use_virtual': 1} BEOFRE?
# 0 INF C?
# {'use_weight': 1, 'use_virtual': 1} THROUG?
# {'use_weight': 1, 'use_virtual': 0} BEOFRE?
# 0 INF C?
# {'use_weight': 1, 'use_virtual': 0} THROUG?
# {'use_weight': 0, 'use_virtual': 1} BEOFRE?
# 0 INF C?
# {'use_weight': 0, 'use_virtual': 1} THROUG?
# 1 C VAL
# {'use_weight': 1, 'use_virtual': 1} BEOFRE?
# 1 INF C?
# {'use_weight': 1, 'use_virtual': 1} THROUG?
# {'use_weight': 1, 'use_virtual': 0} BEOFRE?
# 1 INF C?
# {'use_weight': 0, 'use_virtual': 1} BEOFRE?
# 1 INF C?
# 0 C VAL
# {'use_weight': 1, 'use_virtual': 1} BEOFRE?
# 1 INF C?
# {'use_weight': 1, 'use_virtual': 1} THROUG?
# {'use_weight': 1, 'use_virtual': 0} BEOFRE?
# 1 INF C?
# {'use_weight': 0, 'use_virtual': 1} BEOFRE?
# 1 INF C?
